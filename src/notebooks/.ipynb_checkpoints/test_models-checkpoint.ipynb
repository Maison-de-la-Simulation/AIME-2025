# %%
import sys
import os

# %%
sys.path.append('../..')
from models.utils import *

# %%
# chargement des donner avec les prediction : 
data_path = '../../Data/data_with_predictions/MLP/'
data_dict = load_data(data_path)
